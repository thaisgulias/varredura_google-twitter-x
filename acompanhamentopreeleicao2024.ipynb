# %%
# @title INSTALAÇÕES
from googlesearch import search
import pandas as pd

# %% [markdown]
# ##Links no google- "Problemas "

# %%
# ADICIONE AQUI SUA PALAVRA-CHAVE A SER CONSIDERADA NO FILTRO- AO ADICIONAR UM COMENTARIO USE "#"" NO INICIO DA LINHA

# %%
# Palavras-chave para os filtros
filtros = [
    'reeleição', 'candidato', 'partido', 'política',
    'candidato a prefeito', 'eleição', 'eleição 2024', 'pré candidatura', 'precandidato', 'prefeito apoia', 'aliança', 'pré-candidatos a prefeito', 'Cidadania', 'Robson Magela da Silva'
]

cidade = "Araxá"

# %%
# @title
# Fazendo a pesquisa para cada filtro
for filtro in filtros:
    query = f"Eleição em {cidade} {filtro} 2024"
    print(f"Resultados para {filtro}:")
    search_results = search(query, lang='pt-BR', num=10, stop=10, pause=2)
    for link in search_results:
        print(link)
    print("\n")

# %% [markdown]
# ##Twiter

# %%
pip install ntscraper
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.12-py3-none-any.whl (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ntscraper) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ntscraper) (4.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->ntscraper) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ntscraper) (2024.2.2)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.12

# %%
# @title
from ntscraper import Nitter
import multiprocessing
import pandas as pd

# %%
# @title
scraper = Nitter(0)
# Out:
# Testing instances: 100%|██████████| 30/30 [00:40<00:00,  1.36s/it]

# %%
tweets = scraper.get_tweets("mogidascruzes", mode = 'hashtag', number=1000)

final_tweets = []
for x in tweets['tweets']:
    data = [x['link'], x['text'],x['date'],x['stats']['likes'],x['stats']['comments']]
    final_tweets.append(data)

dat = pd.DataFrame(final_tweets, columns =['twitter_link','text','date','likes','comments'])
dat
# Out:
# WARNING:root:https://nitter.eu.projectsegfau.lt unreachable. Trying https://nitter.soopy.moe
#                                           twitter_link  \
# 0    https://twitter.com/Mohalberth2/status/1746883...
# 1    https://twitter.com/noticiasdemogi/status/1746...
# 2    https://twitter.com/Mohalberth2/status/1746331...
# 3    https://twitter.com/noticiasdemogi/status/1746...
# 4    https://twitter.com/noticiasdemogi/status/1746...
# ..                                                 ...
# 995  https://twitter.com/moginewsonline/status/1691...
# 996  https://twitter.com/noticiasdemogi/status/1691...
# 997  https://twitter.com/moginewsonline/status/1691...
# 998  https://twitter.com/noticiasdemogi/status/1691...
# 999  https://twitter.com/noticiasdemogi/status/1691...
#
#                                                   text  \
# 0    🪹🪺🐦 Sporophila caerulescens Double-collared Se...
# 1    O serviço garante acolhimento familiar provisó...
# 2    🌳🍃🎶🐦📝📷👀 Trogon surrucura Surucua Trogon Surucu...
# 3    A seleção conta com 43 vagas imediatas, além d...
# 4    De acordo com os guardas municipais, a verific...
# ..                                                 ...
# 995  A atriz Léa Garcia, de 90 anos, morreu nesta t...
# 996  A iniciativa da Prefeitura oferece 200 vagas d...
# 997  Até a próxima sexta-feira (18), o Conselho Reg...
# 998  Até o final do mês de agosto, agentes culturai...
# 999  A Prefeitura de Mogi orienta os condutores a t...
#
#                             date  likes  comments
# 0     Jan 15, 2024 · 1:15 PM UTC      3         0
# 1     Jan 15, 2024 · 1:09 PM UTC      0         0
# 2    Jan 14, 2024 · 12:39 AM UTC     35         1
# 3     Jan 15, 2024 · 1:54 AM UTC      0         0
# 4    Jan 15, 2024 · 12:27 AM UTC      0         0
# ..                           ...    ...       ...
# 995   Aug 15, 2023 · 7:50 PM UTC      0         0
# 996   Aug 15, 2023 · 7:47 PM UTC      0         0
# 997   Aug 15, 2023 · 4:45 PM UTC      0         0
# 998   Aug 15, 2023 · 3:25 PM UTC      0         0
# 999   Aug 15, 2023 · 1:47 PM UTC      0         0
#
# [1000 rows x 5 columns]

# %%
# Lista de palavras-chave
filtros = [
    'reeleição', 'candidato', 'partido', 'política',
    'candidato a prefeito', 'eleição', 'eleição 2024', 'pré candidatura', 'precandidato', 'prefeito apoia', 'aliança', 'pré-candidatos a prefeito',
]

# Função para verificar se o texto contém alguma palavra-chave e retornar a palavra-chave encontrada
def encontrar_filtro(texto):
    for filtro in filtros:
        if filtro in texto.lower():
            return filtro
    return None

# Aplicar a função para criar a nova coluna 'filtro' no DataFrame
dat['filtro'] = dat['text'].apply(encontrar_filtro)

# Exibir as linhas onde a coluna 'filtro' não é nula (ou seja, onde uma palavra-chave foi encontrada)
tweets_com_filtros = dat[dat['filtro'].notnull()]

# Exibir apenas as colunas relevantes
tweets_com_filtros = tweets_com_filtros[['twitter_link', 'text', 'date', 'likes', 'comments', 'filtro']]
tweets_com_filtros
# Out:
#                                           twitter_link  \
# 115  https://twitter.com/noticiasdemogi/status/1739...
# 226  https://twitter.com/noticiasdemogi/status/1732...
# 279  https://twitter.com/noticiasdemogi/status/1729...
# 365  https://twitter.com/noticiasdemogi/status/1725...
# 442  https://twitter.com/noticiasdemogi/status/1721...
# 472  https://twitter.com/deboraugusto/status/172013...
# 477  https://twitter.com/noticiasdemogi/status/1719...
#
#                                                   text  \
# 115  Ao todo, 20 conselheiros tutelares foram eleit...
# 226  De acordo com a administração municipal, as op...
# 279  Na hora de estudar para concursos é importante...
# 365  Na hora de estudar para concursos é importante...
# 442  Os postos de trabalho estão distribuídos entre...
# 472  #MogidasCruzes https://noticiasdemogi.com.br/c...
# 477  Neste ano, as provas do Enem serão realizadas ...
#
#                             date  likes  comments     filtro
# 115  Dec 25, 2023 · 11:34 PM UTC      1         0    eleição
# 226    Dec 6, 2023 · 5:56 PM UTC      0         0  candidato
# 279   Nov 29, 2023 · 2:22 PM UTC      0         0  candidato
# 365  Nov 17, 2023 · 11:38 AM UTC      0         0  candidato
# 442    Nov 6, 2023 · 3:03 PM UTC      1         0  candidato
# 472    Nov 2, 2023 · 5:45 PM UTC      0         0  candidato
# 477    Nov 1, 2023 · 4:20 PM UTC      0         0  candidato

# %%
# Contar a frequência das palavras-chave na coluna 'filtro'
frequencia_filtros = tweets_com_filtros['filtro'].value_counts().head(5)

print(frequencia_filtros)
# Out:
# candidato    6
# eleição      1
# Name: filtro, dtype: int64

# %% [markdown]
# Para o principal usuário apontado na análise de hashtag

# %%
# Obtendo tweets do usuário "noticiasdemogi"
news_tweets = scraper.get_tweets("noticiasdemogi", mode='user', number=1000)

# Estruturando os tweets obtidos em um DataFrame
final_news_tweets = []
for x in news_tweets['tweets']:
    data = [x['link'], x['text'], x['date'], x['stats']['likes'], x['stats']['comments']]
    final_news_tweets.append(data)

# Criando um DataFrame com os tweets do usuário "noticiasdemogi"
news_dat = pd.DataFrame(final_news_tweets, columns=['twitter_link', 'text', 'date', 'likes', 'comments'])
news_dat
# Out:
# WARNING:root:Empty page on https://nitter.uni-sonia.com
#                                           twitter_link  \
# 0    https://twitter.com/noticiasdemogi/status/1746...
# 1    https://twitter.com/noticiasdemogi/status/1746...
# 2    https://twitter.com/noticiasdemogi/status/1746...
# 3    https://twitter.com/noticiasdemogi/status/1746...
# 4    https://twitter.com/noticiasdemogi/status/1746...
# ..                                                 ...
# 845  https://twitter.com/noticiasdemogi/status/1721...
# 846  https://twitter.com/noticiasdemogi/status/1721...
# 847  https://twitter.com/noticiasdemogi/status/1721...
# 848  https://twitter.com/noticiasdemogi/status/1721...
# 849  https://twitter.com/noticiasdemogi/status/1721...
#
#                                                   text  \
# 0    Serão ofertadas 20 vagas e as aulas iniciarão ...
# 1    É possível navegar em detalhes em locais como ...
# 2    O serviço garante acolhimento familiar provisó...
# 3    Serão 30 vagas para o curso de Dança Brasil; 1...
# 4    A seleção conta com 43 vagas imediatas, além d...
# ..                                                 ...
# 845  Os 40 loteamentos clandestinos localizados na ...
# 846  As oportunidades são destinadas a mulheres e h...
# 847  O ato deverá contar com a participação da Pref...
# 848  Estudantes ou formados poderão renegociar débi...
# 849  De acordo com a Prefeitura de Mogi das Cruzes,...
#
#                            date  likes  comments
# 0    Jan 15, 2024 · 2:00 PM UTC      0         0
# 1    Jan 15, 2024 · 1:35 PM UTC      1         0
# 2    Jan 15, 2024 · 1:09 PM UTC      0         0
# 3    Jan 15, 2024 · 2:10 AM UTC      0         0
# 4    Jan 15, 2024 · 1:54 AM UTC      0         0
# ..                          ...    ...       ...
# 845  Nov 7, 2023 · 12:35 PM UTC      1         0
# 846  Nov 7, 2023 · 12:28 PM UTC      0         0
# 847  Nov 7, 2023 · 12:11 AM UTC      0         0
# 848  Nov 6, 2023 · 11:37 PM UTC      0         0
# 849  Nov 6, 2023 · 11:16 PM UTC      0         0
#
# [850 rows x 5 columns]

# %%
# Lista de palavras-chave
filtros =[
    'reeleição', 'candidato', 'partido', 'política',
    'candidato a prefeito', 'eleição', 'eleição 2024', 'pré candidatura', 'precandidato', 'prefeito apoia', 'aliança', 'pré-candidatos a prefeito', 'reeleição Caio Cunha'
]

# Função para verificar se o texto contém alguma palavra-chave e retornar a palavra-chave encontrada
def encontrar_filtro(texto):
    for filtro in filtros:
        if filtro in texto.lower():
            return filtro
    return None

# Aplicar a função para criar a nova coluna 'filtro' no DataFrame news_dat
news_dat['filtro'] = news_dat['text'].apply(encontrar_filtro)

# Exibir as linhas onde a coluna 'filtro' não é nula (ou seja, onde uma palavra-chave foi encontrada)
noticiasdemogi_filtros = news_dat[news_dat['filtro'].notnull()]

# Exibir apenas as colunas relevantes
noticiasdemogi_filtros = noticiasdemogi_filtros[['twitter_link', 'text', 'date', 'likes', 'comments', 'filtro']]
noticiasdemogi_filtros
# Out:
#                                           twitter_link  \
# 194  https://twitter.com/noticiasdemogi/status/1740...
# 213  https://twitter.com/noticiasdemogi/status/1739...
# 258  https://twitter.com/noticiasdemogi/status/1737...
# 345  https://twitter.com/noticiasdemogi/status/1734...
# 371  https://twitter.com/noticiasdemogi/status/1734...
# 413  https://twitter.com/noticiasdemogi/status/1732...
# 414  https://twitter.com/noticiasdemogi/status/1732...
# 523  https://twitter.com/noticiasdemogi/status/1729...
# 538  https://twitter.com/noticiasdemogi/status/1729...
# 552  https://twitter.com/noticiasdemogi/status/1729...
# 628  https://twitter.com/noticiasdemogi/status/1727...
# 652  https://twitter.com/noticiasdemogi/status/1726...
# 697  https://twitter.com/noticiasdemogi/status/1725...
# 782  https://twitter.com/noticiasdemogi/status/1723...
#
#                                                   text  \
# 194  De acordo com a administração municipal, as op...
# 213  Ao todo, 20 conselheiros tutelares foram eleit...
# 258  De acordo com a administração municipal, as op...
# 345  O cálculo leva em conta a política de valoriza...
# 371  De acordo com a administração municipal, as op...
# 413  De acordo com a administração municipal, as op...
# 414  De acordo com a administração municipal, as op...
# 523  Na hora de estudar para concursos é importante...
# 538  De acordo com a administração municipal, as op...
# 552  No dia da atividade, os candidatos devem compa...
# 628  Das oportunidades, 55 são destinadas a pessoas...
# 652  De acordo com a administração municipal, as op...
# 697  Na hora de estudar para concursos é importante...
# 782  A jornada de atividade de estágio dos candidat...
#
#                             date  likes  comments     filtro
# 194   Dec 27, 2023 · 3:09 PM UTC      0         0  candidato
# 213  Dec 25, 2023 · 11:34 PM UTC      1         0    eleição
# 258   Dec 20, 2023 · 2:53 PM UTC      1         0  candidato
# 345   Dec 12, 2023 · 7:44 PM UTC      0         0   política
# 371   Dec 11, 2023 · 1:45 PM UTC      0         0  candidato
# 413    Dec 6, 2023 · 5:56 PM UTC      0         0  candidato
# 414    Dec 6, 2023 · 5:54 PM UTC      0         0  candidato
# 523   Nov 29, 2023 · 2:22 PM UTC      0         0  candidato
# 538   Nov 28, 2023 · 3:43 PM UTC      0         0  candidato
# 552   Nov 27, 2023 · 4:28 PM UTC      0         0  candidato
# 628   Nov 22, 2023 · 3:19 PM UTC      0         0  candidato
# 652   Nov 21, 2023 · 1:37 PM UTC      0         0  candidato
# 697  Nov 17, 2023 · 11:38 AM UTC      0         0  candidato
# 782  Nov 10, 2023 · 10:05 PM UTC      0         0  candidato

# %%
# Contar a frequência das palavras-chave na coluna 'filtro'
frequencia_palavras = noticiasdemogi_filtros['filtro'].value_counts()

# Obter as cinco palavras do filtro mais frequentes
cinco_mais_frequentes = frequencia_palavras.head(5)

print(cinco_mais_frequentes)
# Out:
# candidato    12
# eleição       1
# política      1
# Name: filtro, dtype: int64

# %% [markdown]
# Analise da prefeitura de Mogi

# %%
prefeitura = scraper.get_tweets("prefeituramogi", mode='user', number=1000)

# Estruturando os tweets obtidos em um DataFrame
final_prefeitura = []
for x in prefeitura['tweets']:
    data = [x['link'], x['text'], x['date'], x['stats']['likes'], x['stats']['comments']]
    final_prefeitura.append(data)

df_prefeitura = pd.DataFrame(final_prefeitura, columns=['twitter_link', 'text', 'date', 'likes', 'comments'])
df_prefeitura
# Out:
# WARNING:root:https://nitter.moomoo.me unreachable. Trying https://nitter.mint.lgbt
# WARNING:root:Empty page on https://nitter.mint.lgbt
#                                           twitter_link  \
# 0    https://twitter.com/prefeituramogi/status/1745...
# 1    https://twitter.com/prefeituramogi/status/1745...
# 2    https://twitter.com/prefeituramogi/status/1745...
# 3    https://twitter.com/prefeituramogi/status/1745...
# 4    https://twitter.com/prefeituramogi/status/1745...
# ..                                                 ...
# 845  https://twitter.com/prefeituramogi/status/1623...
# 846  https://twitter.com/prefeituramogi/status/1622...
# 847  https://twitter.com/prefeituramogi/status/1622...
# 848  https://twitter.com/prefeituramogi/status/1622...
# 849  https://twitter.com/prefeituramogi/status/1622...
#
#                                                   text  \
# 0    Mais de 110 vagas disponíveis!  🤩 Mogi Conecta...
# 1    👉Serviço Família Acolhedora segue com cadastro...
# 2    👉A partir do dia 15 de janeiro, os mogianos po...
# 3    Operação Cata-Tranqueira 🚛♻️ 📍Vila Natal  📍Jar...
# 4    Tem oportunidades por aqui! 🤩 Crescer da Prefe...
# ..                                                 ...
# 845  Instalação dos 30 totens de segurança em escol...
# 846  Mogi das Cruzes promove Conferência Municipal ...
# 847  Mogi Cidade da Criança é referência internacio...
# 848  Palestras sobre plantas medicinais abrem progr...
# 849  Bom Prato Móvel atende famílias da Região do O...
#
#                            date  likes  comments
# 0    Jan 12, 2024 · 7:39 PM UTC      2         0
# 1    Jan 12, 2024 · 4:09 PM UTC      2         0
# 2    Jan 11, 2024 · 8:01 PM UTC      3         1
# 3    Jan 11, 2024 · 7:03 PM UTC      1         0
# 4    Jan 11, 2024 · 6:15 PM UTC      4         0
# ..                          ...    ...       ...
# 845   Feb 9, 2023 · 3:00 PM UTC      0         0
# 846   Feb 7, 2023 · 3:00 PM UTC      1         0
# 847   Feb 7, 2023 · 2:00 PM UTC      1         0
# 848   Feb 7, 2023 · 1:00 PM UTC      0         0
# 849  Feb 7, 2023 · 12:00 PM UTC      0         0
#
# [850 rows x 5 columns]

# %%
# Função para verificar se o texto contém alguma palavra-chave e retornar a palavra-chave encontrada
def encontrar_filtro_prefeitura(texto):
# 169  Nov 14, 2023 · 4:05 PM UTC      3         0             racismo
# 190   Nov 8, 2023 · 6:00 PM UTC      2         0            educação
# 194   Nov 8, 2023 · 3:16 PM UTC      1         0  assistência social
# 230  Oct 24, 2023 · 7:30 PM UTC      0         0            educação
# 244  Oct 20, 2023 · 7:33 PM UTC      0         0            educação
# 268  Oct 17, 2023 · 4:05 PM UTC      0         0          saneamento
# 277  Oct 11, 2023 · 6:58 PM UTC      0         0  assistência social
# 286  Oct 10, 2023 · 9:00 PM UTC      0         0  assistência social
# 304   Oct 9, 2023 · 5:01 PM UTC      0         0              esgoto
# 305   Oct 9, 2023 · 4:01 PM UTC      0         0            educação
# 324   Oct 3, 2023 · 4:00 PM UTC      0         0            educação
# 337  Sep 29, 2023 · 6:26 PM UTC      0         0            educação
# 348  Sep 28, 2023 · 6:13 PM UTC      0         1            educação
# 361  Sep 27, 2023 · 4:38 PM UTC      1         0              creche
# 367  Sep 26, 2023 · 6:26 PM UTC      0         0            educação
# 407  Sep 19, 2023 · 8:04 PM UTC      0         0           castração
# 413  Sep 19, 2023 · 4:01 PM UTC      1         0            educação
# 416  Sep 18, 2023 · 8:14 PM UTC      1         0           castração
# 429  Sep 15, 2023 · 6:27 PM UTC      0         0           violência
# 440  Sep 13, 2023 · 8:21 PM UTC      0         0            educação
# 441  Sep 13, 2023 · 6:01 PM UTC      0         0           matrícula
# 449  Sep 12, 2023 · 5:59 PM UTC      0         0            educação
# 452  Sep 12, 2023 · 4:57 PM UTC      0         1           violência

# %%
# Contar a frequência das palavras-chave na coluna 'filtro' para a prefeitura
frequencia_filtros_prefeitura = prefeitura_filtros['filtro'].value_counts()

print(frequencia_filtros_prefeitura)
# Out:
# educação              18
# assistência social     6
# violência              5
# esgoto                 3
# castração              2
# cras                   1
# racismo                1
# saneamento             1
# creche                 1
# matrícula              1
# Name: filtro, dtype: int64

# %% [markdown]
# Interações

# %%
# Identificar as 10 linhas com mais likes no DataFrame df_prefeitura
top_likes = df_prefeitura.nlargest(10, 'likes')[['twitter_link', 'text', 'date', 'likes', 'comments']]

# Identificar as 10 linhas com mais comments no DataFrame df_prefeitura
top_comments = df_prefeitura.nlargest(10, 'comments')[['twitter_link', 'text', 'date', 'likes', 'comments']]

# Exibir as tabelas das 10 linhas com mais likes e comments
df_top_likes = pd.DataFrame(top_likes)
df_top_comments = pd.DataFrame(top_comments)

# %%
df_top_likes
# Out:
#                                           twitter_link  \
# 202  https://twitter.com/mogibasquete/status/172120...
# 489  https://twitter.com/prefeituramogi/status/1694...
# 201  https://twitter.com/prefeituramogi/status/1721...
# 210  https://twitter.com/prefeituramogi/status/1719...
# 317  https://twitter.com/prefeituramogi/status/1709...
# 32   https://twitter.com/prefeituramogi/status/1734...
# 170  https://twitter.com/prefeituramogi/status/1724...
# 459  https://twitter.com/prefeituramogi/status/1701...
# 473  https://twitter.com/prefeituramogi/status/1698...
# 167  https://twitter.com/prefeituramogi/status/1724...
#
#                                                   text  \
